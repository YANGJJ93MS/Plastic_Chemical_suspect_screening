# %%
##this script is used for extracting the ms2 data from the targetd msms data and used for spectrum comparison.

# %%
#helper functions

# !pip install pyopenms
# !pip install numpy
# !pip install tabulate
# !pip install matchms

import re
import numpy as np
import matchms 
from matchms import calculate_scores
from matchms import Spectrum
from matchms.similarity import CosineGreedy
import pandas as pd
import pyopenms as oms
import tabulate
import os 
import copy
import warnings
# Suppress specific warnings
warnings.filterwarnings("ignore", message=".*")

def ppm_error(mz, target):
    return abs(mz - target) / target * 1e6

def preprocess_spectra(filepath, target_mz, ce_level, tolerance=5):
    # Extract spectra with specified collision energy level
    # Filter spectra based on targeted m/z value
    if target_mz is None:
        raise ValueError("Please provide a target m/z value.")
    ce_level = float(ce_level)
    tolerance = float(tolerance)
    target_mz = float(target_mz)
    spectra = oms.MSExperiment()
    oms.MzMLFile().load(filepath, spectra)
    ms2_spec = spectra.getSpectra()

    ms2_query = oms.MSExperiment()
    for s in ms2_spec:
        if s.getMSLevel() == 1:
            continue
        precursors = s.getPrecursors()
        mslevel = s.getMSLevel()
        collision_energy = precursors[0].getMetaValue("collision energy")
        ms_error = ppm_error(precursors[0].getMZ(), target_mz)
        if ms_error < tolerance and mslevel == 2 and collision_energy == ce_level:
            ms2_query.addSpectrum(s)
        else :
            continue

    ms2beforemerg = [s for s in ms2_query.getSpectra() if s.getMSLevel() == 2]
    print(f'Number of MS2 spectra before merge: {len(ms2beforemerg)}')

    if len(ms2beforemerg) == 0:
        print(f"No spectra found with specified parameters for {ce_level}.")
        return None
    
    elif len(ms2beforemerg) >= 1:
        #merget the ms spectra
        merger = oms.SpectraMerger()
        param = merger.getParameters()
        param.setValue("mz_tolerance", 1e-3)
        param.setValue("rt_tolerance", "5.0")
        merger.setParameters(param)
        merger.mergeSpectraPrecursors(ms2_query)
        ms2aftermerg = [s for s in ms2_query.getSpectra() if s.getMSLevel() == 2]
        # print(f'Number of MS2 spectra after merge: {len(ms2aftermerg)}')
        return ms2_query


def parse_msp_file(msp_file_path, polarity):
    """
    Parses the .msp file to extract all spectrum information.
    
    Args:
        msp_file_path (str): Path to the .msp file.

    Returns:
        dict: A dictionary where keys are InChIKey or SMILES and values are lists of spectra data.
    """
    spectra = {}
    if polarity == "positive":
        p_type = "[M+H]+"
    elif polarity == "negative":
        p_type = "[M-H]-"
    else:
        raise ValueError("Invalid polarity. Please specify 'positive' or 'negative'.")
    
    with open(msp_file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        entries = content.split('Name: ')
        for entry in entries[1:]:
            lines = entry.strip().split('\n')
            metadata = {}
            spectrum_data = []
            key = None

            for line in lines:
                if line.startswith("InChIKey:"):
                    key = line.split(": ")[1].strip()
                elif line.startswith("SMILES:") and key is None:
                    key = line.split(": ")[1].strip()
                elif line.startswith("Spectrum_type:"):
                    spectrum_type = line.split(": ")[1].strip()
                elif line.startswith("Precursor_type:"):
                    precursor_type = line.split(": ")[1].strip()
                elif line.startswith("Num Peaks:"):
                    num_peaks = int(line.split(": ")[1].strip())
                    spectrum_data = lines[lines.index(line)+1:lines.index(line)+1+num_peaks]
                elif ": " in line:
                    k, v = line.split(": ", 1)
                    metadata[k.strip()] = v.strip()

            # Retain only spectra with "Spectrum_type: MS2"
            if spectrum_type == "MS2" and precursor_type == p_type  and key and spectrum_data:
                if key not in spectra:
                    spectra[key] = []
                spectra[key].append({
                    "metadata": metadata,
                    "spectrum": [(float(mz), float(intensity)) for mz, intensity in (line.split() for line in spectrum_data)]
                })

    return spectra


def parse_mona_database(db_file_path, polarity):
    """
    Parses an alternate database format to extract all spectrum information based on polarity.

    Args:
        db_file_path (str): Path to the database file.
        polarity (str): The ion polarity to filter ("positive" or "negative").

    Returns:
        dict: A dictionary where keys are InChIKey or SMILES and values are lists of spectra data.
    """
    spectra = {}

    if polarity == "positive":
        p_type = "[M+H]+"
    elif polarity == "negative":
        p_type = "[M-H]-"
    else:
        raise ValueError("Invalid polarity. Please specify 'positive' or 'negative'.")

    with open(db_file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        entries = content.split('NAME: ')  # "NAME:" marks the beginning of each spectrum.
        for entry in entries[1:]:
            lines = entry.strip().split('\n')
            metadata = {}
            spectrum_data = []
            key = None

            for line in lines:
                if line.startswith("INCHIKEY:"):
                    key = line.split(": ")[1].strip()
                elif line.startswith("SMILES:") and key is None:
                    key = line.split(": ")[1].strip()
                elif line.startswith("PRECURSORTYPE:"):
                    ionization = line.split(": ")[1].strip()
                elif line.startswith("Num Peaks:"):
                    num_peaks = int(line.split(": ")[1].strip())
                    spectrum_data = [tuple(map(float, peak.split())) for peak in lines[lines.index(line)+1:] if peak.strip()]
                elif ": " in line:
                    k, v = line.split(": ", 1)
                    metadata[k.strip()] = v.strip()

            # Retain only spectra matching the desired polarity
            if ionization == p_type and key and spectrum_data:
                if key not in spectra:
                    spectra[key] = []
                spectra[key].append({
                    "metadata": metadata,
                    "spectrum": spectrum_data
                })

    return spectra

# %%
##prepare database for spectrum matching
database1 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/MassBank_NIST.msp"
database2 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/MSMS_Public_EXP_NEG_VS17.msp"
database10 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/MSMS_Public_EXP_POS_VS17.msp"
database3 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/MoNA-export-All_LC-MS-MS_Orbitrap.msp"

#CFMID database
database4 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/CFMID-plastic/compiled_spectrum_library_neg_energy0.msp"
database5 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/CFMID-plastic/compiled_spectrum_library_neg_energy1.msp"
database6 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/CFMID-plastic/compiled_spectrum_library_neg_energy2.msp"

database7 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/CFMID-plastic/compiled_spectrum_library_pos_energy0.msp"
database8 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/CFMID-plastic/compiled_spectrum_library_pos_energy1.msp"
database9 = "D:/UCSF_postdoc_topic/REVEAL_topics/Spectrum_database/CFMID-plastic/compiled_spectrum_library_pos_energy2.msp"

mbank_data_neg = parse_msp_file(database1, polarity="negative")
mona_data_neg = parse_mona_database(database2, polarity="negative")
mona_obtrap_data_neg = parse_msp_file(database3, polarity="negative")
cfmid_e0_data_neg = parse_mona_database(database4, polarity="negative")
cfmid_e1_data_neg = parse_mona_database(database5, polarity="negative")
cfmid_e2_data_neg = parse_mona_database(database6, polarity="negative")

mbank_data_pos = parse_msp_file(database1, polarity="positive")
mona_data_pos = parse_mona_database(database10, polarity="positive")
mona_obtrap_data_pos = parse_msp_file(database3, polarity="positive")
cfmid_e0_data_pos = parse_mona_database(database7, polarity="positive")
cfmid_e1_data_pos = parse_mona_database(database8, polarity="positive")
cfmid_e2_data_pos = parse_mona_database(database9, polarity="positive")

# %% [markdown]
# ##library and insilico predicted spectrum matching

# %%
##import the list of suspected compounds for spectrum match
posfilepath = "D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Pos_AlignmentResults/feature_annotation_RTMS_pos_peakover5000_MSMS_injection.csv"
negfilepath = "D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Neg_AlignmentResults/feature_annotation_RTMS_neg_peakover5000_MSMS_injection.csv"
postarget  = pd.read_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Pos_AlignmentResults/feature_annotation_RTMS_pos_peakover5000_MSMS_injection.csv")
negtarget = pd.read_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Neg_AlignmentResults/feature_annotation_RTMS_neg_peakover5000_MSMS_injection.csv")

#select rows with not 'NotMatched'value in MSMS_injection column for each files
postarget = postarget[postarget['MSMS_injection'] != 'NotMatched']
negtarget = negtarget[negtarget['MSMS_injection'] != 'NotMatched']

postarget['MSMS_injection'] = postarget['MSMS_injection'].astype(str)
postarget['MSMS_injection'] = 'B1-10-MSMS-pos_I' + postarget['MSMS_injection']

negtarget['MSMS_injection'] = negtarget['MSMS_injection'].astype(str)
negtarget['MSMS_injection'] = 'B1-10-MSMS-neg_I' + negtarget['MSMS_injection']
# print(tabulate.tabulate(negtarget, headers='keys', tablefmt='pretty'))

# %%
#step1 extract the spectra from the database for each inquiry compound
#step2 extract the experimental spectrum from standard msms data for each inquiry compound
#step3 calculate the similarity score for each inquiry compound
#step4 save the similarity score for each inquiry compound from each database
#step5 report the results

# %%
def get_spectrum_by_key(spectra, key):
    """
    Retrieves all spectrum information by InChIKey or SMILES.

    Args:
        spectra (dict): Parsed spectra data.
        key (str): The InChIKey or SMILES to search for.

    Returns:
        dict: A dictionary where keys are collision energies and values are spectra.
    """
    if key not in spectra:
        return {}

    grouped_spectra = {}
    for spec in spectra[key]:
        collision_energy = spec["metadata"].get("Collision_energy", spec["metadata"].get("COLLISIONENERGY", "Unknown"))
        if collision_energy not in grouped_spectra:
            grouped_spectra[collision_energy] = []
        grouped_spectra[collision_energy].append(spec["spectrum"])

    return grouped_spectra

def normalize_and_filter(spectrum, baseline):
    try:
        mz, intensity = spectrum.get_peaks()
    except AttributeError: 
        if isinstance(spectrum, list) and all(isinstance(i, tuple) for i in spectrum):
            mz, intensity = zip(*spectrum)
            mz = np.array(mz)
            intensity = np.array(intensity)
        else:
            raise ValueError("Spectrum format is not recognized.")
    except:
        if isinstance(spectrum, tuple) and len(spectrum) == 2:
            mz = np.array(spectrum[0])
            intensity = np.array(spectrum[1])
        else:
            raise ValueError("Spectrum format is not recognized.")
    
    intensity = np.round((intensity / max(intensity)) * 100, 1)
    indices = np.where(intensity >= baseline)
    return np.array(mz[indices]), np.array(intensity[indices])

# %%
##set threshold for peak matching
match_tolerance = 0.005 #dalton
peak_int_tol = 5 #ppm
peak_norm_tol = 5 #%

##import library for spectrum comparison
#perform spectrum search for each row by InChiKey_origin column, and add number of found spectra to the dataframe from each database.
for iter, row in negtarget.iterrows():
    key = row['InChiKey_origin']
    mbank_spectra = get_spectrum_by_key(mbank_data_neg, key)
    mona_spectra = get_spectrum_by_key(mona_data_neg, key)
    mona_obtrap_spectra = get_spectrum_by_key(mona_obtrap_data_neg, key)
    cfmid_e0_spectra = get_spectrum_by_key(cfmid_e0_data_neg, key)
    cfmid_e1_spectra = get_spectrum_by_key(cfmid_e1_data_neg, key)   
    cfmid_e2_spectra = get_spectrum_by_key(cfmid_e2_data_neg, key)
    negtarget.loc[iter, 'mbank_data_neg'] = len(mbank_spectra.keys())
    negtarget.loc[iter, 'mona_spectra_neg'] = len(mona_spectra.keys())
    negtarget.loc[iter, 'mona_obtrap_spectra_neg'] = len(mona_obtrap_spectra.keys())
    negtarget.loc[iter, 'cfmid_e0_spectra_neg'] = len(cfmid_e0_spectra.keys())
    negtarget.loc[iter, 'cfmid_e1_spectra_neg'] = len(cfmid_e1_spectra.keys())
    negtarget.loc[iter, 'cfmid_e2_spectra_neg'] = len(cfmid_e2_spectra.keys())
    negtarget.loc[iter, 'total_spectra_neg'] = len(mbank_spectra.keys()) + len(mona_spectra.keys()) + len(mona_obtrap_spectra.keys()) + len(cfmid_e0_spectra.keys()) + len(cfmid_e1_spectra.keys()) + len(cfmid_e2_spectra.keys())


#extract the experimental spectrum for each compound
for iter, row in negtarget.iterrows():
    if row['total_spectra_neg'] == 0:
        print(f'no spectra found for this compound {row["InChiKey_origin"]}')
        continue
    
    #perform spectrum similarity for each database
    query_spectrums =[]
    #extract the experimental spectrum
    key = row['InChiKey_origin']
    print(f'Searching for compound {key}')

    target_mz = row['Average Mz']
    injection_id = row['MSMS_injection']
    q_filepath = os.path.join("D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/", f"{injection_id}.mzML")

    celevel = [10,20,40]
    for ce in celevel:
        ms2_query = preprocess_spectra(q_filepath, target_mz, ce, tolerance=peak_int_tol)
        if ms2_query is None:
            print(f'No spectra found for compound {key} with CE {ce}')
            continue
        sspectrum = Spectrum(mz = normalize_and_filter(ms2_query[0], baseline=peak_norm_tol)[0],
                             intensities = normalize_and_filter(ms2_query[0], baseline=peak_norm_tol)[1], metadata = {"inchikey": key, 'peak_comments':  str(ce)+'eV'})
        query_spectrums.append(sspectrum)
    print(f'finished extracting experimental spectrum for compound {key}----------------------------------------')
    
    #############
    #extract the reference database spectra for each compound
    reference_spectrums_library = []
    reference_spectrums_insilico =[]
    if row['mbank_data_neg'] > 0:
        mbank_spectra = get_spectrum_by_key(mbank_data_neg, key)
        for ce, spectra in mbank_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {'inchikey': key, 'peak_comments': 'mbank' + '_'+ str(ce)})
                reference_spectrums_library.append(reference)

    if row['mona_spectra_neg'] > 0:
        mona_spectra = get_spectrum_by_key(mona_data_neg, key)
        for ce, spectra in mona_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'mona' + '_'+ str(ce)})
                reference_spectrums_library.append(reference)

    if row['mona_obtrap_spectra_neg'] > 0:
        mona_obtrap_spectra = get_spectrum_by_key(mona_obtrap_data_neg, key)
        for ce, spectra in mona_obtrap_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'mona_obtrap' + '_'+ str(ce)})
                reference_spectrums_library.append(reference)

    if row['cfmid_e0_spectra_neg'] > 0:
        cfmid_e0_spectra = get_spectrum_by_key(cfmid_e0_data_neg, key)
        for ce, spectra in cfmid_e0_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'cfmid_e0' + '_'+ str(ce)})
                reference_spectrums_insilico.append(reference)

    if row['cfmid_e1_spectra_neg'] > 0:
        cfmid_e1_spectra = get_spectrum_by_key(cfmid_e1_data_neg, key)
        for ce, spectra in cfmid_e1_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'cfmid_e1' + '_'+ str(ce)})
                reference_spectrums_insilico.append(reference)
        
    if row['cfmid_e2_spectra_neg'] > 0:
        cfmid_e2_spectra = get_spectrum_by_key(cfmid_e2_data_neg, key)
        for ce, spectra in cfmid_e2_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'cfmid_e3' + '_'+ str(ce)})
                reference_spectrums_insilico.append(reference)

    print(f'finished extracting reference spectrum for compound {key}----------------------------------------')
    
    #calculate the similarity score for each database
    print(f'Spectrum similarity-----------------')
    print(f'number of library spectra found for this compound {len(reference_spectrums_library)}')
    print(f'number of insilico spectra found for this compound {len(reference_spectrums_insilico)}')
    # print(reference_spectrums[1].metadata)

    if len(reference_spectrums_library) > 0:
        try:
            scores = matchms.calculate_scores(references = reference_spectrums_library,
                                        queries = query_spectrums,
                                        similarity_function = CosineGreedy(tolerance=match_tolerance, 
                                                                        mz_power=1.3, 
                                                                        intensity_power=0.53),
                                        is_symmetric = False)
            
            best_scores_library, best_spectrums_library, best_match_querys_library = [], [],[]

            for i in range(len(query_spectrums)):
                query = query_spectrums[i]
                best_matches = scores.scores_by_query(query,'CosineGreedy_score', sort=True)
                for (reference, score) in best_matches:
                    best_scores_library.append(score[0])
                    best_spectrums_library.append(reference.metadata['peak_comments'])
                    best_match_querys_library.append(query.metadata['peak_comments'])

            #get the highest score and the corresponding database
            if best_scores_library:
                best_score_library = max(best_scores_library)
                best_spectrum_library = best_spectrums_library[best_scores_library.index(best_score_library)]
                best_match_query_library = best_match_querys_library[best_scores_library.index(best_score_library)]

            else:
                best_score_library = None
                best_spectrum_library = None
                best_match_query_library = None
        
        except IndexError:
            print(f'No match found for compound {key}')
            best_score_library = None
            best_spectrum_library = None
            best_match_query_library = None
        
        except ValueError:
            print(f'No match found for compound {key}')
            best_score_library = None
            best_spectrum_library = None
            best_match_query_library = None
    else:
        best_score_library = None
        best_spectrum_library = None
        best_match_query_library = None
     

    if len(reference_spectrums_insilico) > 0:
        try:
            scores = matchms.calculate_scores(references = reference_spectrums_insilico,
                                        queries = query_spectrums,
                                        similarity_function = CosineGreedy(tolerance=match_tolerance, 
                                                                        mz_power=1.3, 
                                                                        intensity_power=0.53),
                                        is_symmetric = False)
            
            best_scores_insilico, best_spectrums_insilico, best_match_querys_insilico = [], [],[]

            for i in range(len(query_spectrums)):
                query = query_spectrums[i]
                best_matches = scores.scores_by_query(query,'CosineGreedy_score', sort=True)
                for (reference, score) in best_matches:
                    best_scores_insilico.append(score[0])
                    best_spectrums_insilico.append(reference.metadata['peak_comments'])
                    best_match_querys_insilico.append(query.metadata['peak_comments'])

            #get the highest score and the corresponding database
            if best_scores_insilico:
                best_score_insilico = max(best_scores_insilico)
                best_spectrum_insilico = best_spectrums_insilico[best_scores_insilico.index(best_score_insilico)]
                best_match_query_insilico = best_match_querys_insilico[best_scores_insilico.index(best_score_insilico)]

            else:
                best_score_insilico = None
                best_spectrum_insilico = None
                best_match_query_insilico = None
        
        except IndexError:
            print(f'No match found for compound {key}')
            best_score_insilico = None
            best_spectrum_insilico = None
            best_match_query_insilico = None
        
        except ValueError:
            print(f'No match found for compound {key}')
            best_score_insilico = None
            best_spectrum_insilico = None
            best_match_query_insilico = None
    else:
        best_score_insilico = None
        best_spectrum_insilico = None
        best_match_query_insilico = None
    
    negtarget.loc[iter, 'library_best_match'] = best_spectrum_library
    negtarget.loc[iter, 'library_best_match_query'] = best_match_query_library
    negtarget.loc[iter, 'library_best_match_score_value'] = best_score_library
    negtarget.loc[iter, 'insilico_best_match'] = best_spectrum_insilico
    negtarget.loc[iter, 'insilico_best_match_query'] = best_match_query_insilico
    negtarget.loc[iter, 'insilico_best_match_score_value'] = best_score_insilico

    print(f'Finished spectrum matching for compound {key}')
# Out:
# Searching for compound UIAFKZKHHVMJGS-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 12
# 2024-12-29 14:06:51,416:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 12
# 2024-12-29 14:06:52,320:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 12
# 2024-12-29 14:06:53,177:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound UIAFKZKHHVMJGS-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:06:53,177:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:06:53,177:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:06:53,177:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound UIAFKZKHHVMJGS-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound UIAFKZKHHVMJGS-UHFFFAOYSA-N
# Searching for compound MWOOGOJBHIARFG-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:00,295:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:01,209:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:02,123:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound MWOOGOJBHIARFG-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:02,124:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,125:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,126:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,126:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,128:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,128:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,130:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,130:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,131:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,131:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,134:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,134:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,135:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,138:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,140:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,141:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,142:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,143:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,145:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,145:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:02,146:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MWOOGOJBHIARFG-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 23
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MWOOGOJBHIARFG-UHFFFAOYSA-N
# Searching for compound KMOUUZVZFBCRAM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:04,242:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:05,140:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:06,000:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound KMOUUZVZFBCRAM-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:06,000:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:06,000:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:06,000:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound KMOUUZVZFBCRAM-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound KMOUUZVZFBCRAM-UHFFFAOYSA-N
# Searching for compound LXCFILQKKLGQFO-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:06,905:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:07,821:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:08,711:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound LXCFILQKKLGQFO-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:08,722:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,723:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,724:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,725:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,726:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,727:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,728:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,729:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,730:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,731:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,732:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,733:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,734:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,735:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,736:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,737:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,739:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,740:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,741:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,742:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,744:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,747:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,748:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,749:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,749:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,750:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,751:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,752:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:08,753:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound LXCFILQKKLGQFO-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 26
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound LXCFILQKKLGQFO-UHFFFAOYSA-N
# Searching for compound OSWPMRLSEDHDFF-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:10,875:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:11,739:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:12,689:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound OSWPMRLSEDHDFF-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:12,697:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:12,697:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:12,698:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:12,699:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:12,700:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:12,701:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound OSWPMRLSEDHDFF-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 3
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound OSWPMRLSEDHDFF-UHFFFAOYSA-N
# Searching for compound KMOUUZVZFBCRAM-OLQVQODUSA-N
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:13,605:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:14,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:15,394:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound KMOUUZVZFBCRAM-OLQVQODUSA-N----------------------------------------
# 2024-12-29 14:07:15,395:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:15,395:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:15,397:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound KMOUUZVZFBCRAM-OLQVQODUSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound KMOUUZVZFBCRAM-OLQVQODUSA-N
# Searching for compound HMMBJOWWRLZEMI-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:16,295:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:17,183:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 23
# 2024-12-29 14:07:18,129:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound HMMBJOWWRLZEMI-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:18,129:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:18,129:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:18,145:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound HMMBJOWWRLZEMI-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound HMMBJOWWRLZEMI-UHFFFAOYSA-N
# Searching for compound ZXVONLUNISGICL-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:19,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:20,030:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound ZXVONLUNISGICL-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,991:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,991:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:20,991:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound ZXVONLUNISGICL-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 52
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound ZXVONLUNISGICL-UHFFFAOYSA-N
# Searching for compound WOZVHXUHUFLZGK-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:21,949:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:22,836:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:23,798:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound WOZVHXUHUFLZGK-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:23,800:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:23,800:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:23,800:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound WOZVHXUHUFLZGK-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound WOZVHXUHUFLZGK-UHFFFAOYSA-N
# Searching for compound NIQCNGHVCWTJSM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:24,727:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:25,611:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:26,518:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound NIQCNGHVCWTJSM-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:26,519:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:26,520:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:26,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound NIQCNGHVCWTJSM-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound NIQCNGHVCWTJSM-UHFFFAOYSA-N
# Searching for compound STOUHHBZBQBYHH-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:27,373:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:28,272:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:29,175:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound STOUHHBZBQBYHH-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:29,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:29,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:29,182:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound STOUHHBZBQBYHH-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound STOUHHBZBQBYHH-UHFFFAOYSA-N
# Searching for compound VNGOYPQMJFJDLV-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:30,077:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:31,033:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:07:32,020:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound VNGOYPQMJFJDLV-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:32,021:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:32,022:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:32,022:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound VNGOYPQMJFJDLV-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound VNGOYPQMJFJDLV-UHFFFAOYSA-N
# Searching for compound MGMSZKIPUNOMCS-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:32,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:33,933:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:34,855:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound MGMSZKIPUNOMCS-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:34,855:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:34,855:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:34,855:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MGMSZKIPUNOMCS-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MGMSZKIPUNOMCS-UHFFFAOYSA-N
# Searching for compound LNGAGQAGYITKCW-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:35,793:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:36,740:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:37,716:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound LNGAGQAGYITKCW-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:37,717:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:37,718:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:37,719:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound LNGAGQAGYITKCW-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound LNGAGQAGYITKCW-UHFFFAOYSA-N
# Searching for compound JPFPDGRVRGETED-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:38,662:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:39,653:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:40,621:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound JPFPDGRVRGETED-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:40,621:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:40,621:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:40,621:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound JPFPDGRVRGETED-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound JPFPDGRVRGETED-UHFFFAOYSA-N
# Searching for compound STGXUBIZGYMIRM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:41,577:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:42,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:43,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound STGXUBIZGYMIRM-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:43,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:43,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:43,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound STGXUBIZGYMIRM-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound STGXUBIZGYMIRM-UHFFFAOYSA-N
# Searching for compound AXKZIDYFAMKWSA-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:44,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:45,431:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:46,355:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound AXKZIDYFAMKWSA-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:46,356:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:46,356:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:46,356:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound AXKZIDYFAMKWSA-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound AXKZIDYFAMKWSA-UHFFFAOYSA-N
# Searching for compound SGPZSOQUJLFTMQ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:07:47,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:07:48,342:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:07:49,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound SGPZSOQUJLFTMQ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:49,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:49,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:49,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound SGPZSOQUJLFTMQ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound SGPZSOQUJLFTMQ-UHFFFAOYSA-N
# Searching for compound QUKGYYKBILRGFE-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:50,292:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:51,249:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound QUKGYYKBILRGFE-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:52,197:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound QUKGYYKBILRGFE-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 4
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound QUKGYYKBILRGFE-UHFFFAOYSA-N
# Searching for compound MTZQAGJQAFMTAQ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:53,144:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:54,037:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:54,975:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound MTZQAGJQAFMTAQ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:54,980:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:54,980:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:54,980:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MTZQAGJQAFMTAQ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MTZQAGJQAFMTAQ-UHFFFAOYSA-N
# Searching for compound QSSJZLPUHJDYKF-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:55,912:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:56,855:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:57,807:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound QSSJZLPUHJDYKF-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:07:57,807:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:57,807:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:07:57,807:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound QSSJZLPUHJDYKF-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound QSSJZLPUHJDYKF-UHFFFAOYSA-N
# Searching for compound FQYUMYWMJTYZTK-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:58,759:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:07:59,688:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:00,594:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound FQYUMYWMJTYZTK-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:00,594:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:00,594:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:00,594:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound FQYUMYWMJTYZTK-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound FQYUMYWMJTYZTK-UHFFFAOYSA-N
# Searching for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:01,588:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:02,531:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:03,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:03,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:03,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:03,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N
# Searching for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:04,528:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:05,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:06,578:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:06,580:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:06,582:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:06,584:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:06,585:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 1
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N
# Searching for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:08:14,973:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:08:15,909:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:08:16,836:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:16,837:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:16,838:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:16,838:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound HIDBROSJWZYGSZ-UHFFFAOYSA-N
# Searching for compound SMIOEQSLJNNKQF-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:17,826:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:18,710:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 6
# 2024-12-29 14:08:19,657:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound SMIOEQSLJNNKQF-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:19,658:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:19,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:19,659:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound SMIOEQSLJNNKQF-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound SMIOEQSLJNNKQF-UHFFFAOYSA-N
# Searching for compound YQHLDYVWEZKEOX-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:20,556:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:21,458:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:22,382:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound YQHLDYVWEZKEOX-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:22,384:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:22,385:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:22,385:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound YQHLDYVWEZKEOX-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound YQHLDYVWEZKEOX-UHFFFAOYSA-N
# Searching for compound CUZKCNWZBXLAJX-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:23,310:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:24,235:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:25,236:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound CUZKCNWZBXLAJX-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:25,243:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:25,243:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:25,244:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound CUZKCNWZBXLAJX-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound CUZKCNWZBXLAJX-UHFFFAOYSA-N
# Searching for compound AUFZRCJENRSRLY-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:26,256:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:27,236:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:28,125:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound AUFZRCJENRSRLY-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:28,125:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:28,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:28,133:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound AUFZRCJENRSRLY-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound AUFZRCJENRSRLY-UHFFFAOYSA-N
# Searching for compound IBLKWZIFZMJLFL-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:29,092:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:30,055:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:30,999:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound IBLKWZIFZMJLFL-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:30,999:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:31,007:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:31,008:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound IBLKWZIFZMJLFL-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# No match found for compound IBLKWZIFZMJLFL-UHFFFAOYSA-N
# Finished spectrum matching for compound IBLKWZIFZMJLFL-UHFFFAOYSA-N
# Searching for compound YOURXVGYNVXQKT-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:08:31,923:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:08:32,860:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:08:33,831:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound YOURXVGYNVXQKT-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:33,833:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:33,833:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:33,834:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound YOURXVGYNVXQKT-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound YOURXVGYNVXQKT-UHFFFAOYSA-N
# Searching for compound XESZUVZBAMCAEJ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:34,839:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:35,840:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:08:36,796:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound XESZUVZBAMCAEJ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:08:36,797:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,798:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,799:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,800:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,802:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,803:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,803:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,804:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,805:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,806:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:08:36,808:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# ...
# finished extracting reference spectrum for compound FVKRIDSRWFEQME-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound FVKRIDSRWFEQME-UHFFFAOYSA-N
# Searching for compound FLIACVVOZYBSBS-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:30,716:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:31,738:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:32,716:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound FLIACVVOZYBSBS-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:32,717:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:32,717:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:32,718:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound FLIACVVOZYBSBS-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound FLIACVVOZYBSBS-UHFFFAOYSA-N
# Searching for compound KEMQGTRYUADPNZ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:33,754:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:34,766:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:35,760:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound KEMQGTRYUADPNZ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:35,760:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,761:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,762:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,763:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,764:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,764:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,766:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,767:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,767:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,768:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,768:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,769:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,770:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,770:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,771:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,771:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,775:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,776:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,777:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:35,778:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound KEMQGTRYUADPNZ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 17
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound KEMQGTRYUADPNZ-UHFFFAOYSA-N
# Searching for compound LCVHZNSIAYNAGX-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:36,887:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:37,903:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:38,919:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound LCVHZNSIAYNAGX-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:38,921:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:38,921:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:38,922:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound LCVHZNSIAYNAGX-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound LCVHZNSIAYNAGX-UHFFFAOYSA-N
# Searching for compound CCFWAONPPYWNDM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:39,942:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:40,980:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:18:42,007:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound CCFWAONPPYWNDM-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:42,008:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:42,009:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:42,010:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound CCFWAONPPYWNDM-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound CCFWAONPPYWNDM-UHFFFAOYSA-N
# Searching for compound RFVNOJDQRGSOEL-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:18:43,030:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:18:44,041:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:18:44,997:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound RFVNOJDQRGSOEL-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:44,998:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:44,999:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:45,000:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound RFVNOJDQRGSOEL-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound RFVNOJDQRGSOEL-UHFFFAOYSA-N
# Searching for compound QQVHEQUEHCEAKS-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:18:45,982:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:18:46,969:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:18:47,948:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound QQVHEQUEHCEAKS-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:47,949:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:47,949:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:47,950:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound QQVHEQUEHCEAKS-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound QQVHEQUEHCEAKS-UHFFFAOYSA-N
# Searching for compound LGBAGUMSAPUZPU-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:18:48,946:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:18:49,965:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 9
# 2024-12-29 14:18:51,005:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound LGBAGUMSAPUZPU-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:51,008:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:51,008:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:51,009:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound LGBAGUMSAPUZPU-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound LGBAGUMSAPUZPU-UHFFFAOYSA-N
# Searching for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 25
# 2024-12-29 14:18:52,045:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 25
# 2024-12-29 14:18:53,049:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 25
# 2024-12-29 14:18:54,063:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:54,064:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:54,065:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:54,066:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N
# Searching for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:18:55,058:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:18:56,058:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:18:57,075:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:18:57,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:57,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:18:57,078:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound OKMWKBLSFKFYGZ-UHFFFAOYSA-N
# Searching for compound QWVBGCWRHHXMRM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:18:58,028:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:18:59,037:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:00,013:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound QWVBGCWRHHXMRM-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:00,014:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:00,015:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:00,016:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound QWVBGCWRHHXMRM-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound QWVBGCWRHHXMRM-UHFFFAOYSA-N
# Searching for compound FIBARIGPBPUBHC-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 22
# 2024-12-29 14:19:00,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 22
# 2024-12-29 14:19:01,886:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 22
# 2024-12-29 14:19:02,851:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound FIBARIGPBPUBHC-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:02,853:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:02,853:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:02,854:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound FIBARIGPBPUBHC-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound FIBARIGPBPUBHC-UHFFFAOYSA-N
# Searching for compound PUYRISKXBBQECH-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 22
# 2024-12-29 14:19:03,816:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 22
# 2024-12-29 14:19:04,751:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 22
# 2024-12-29 14:19:05,699:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting experimental spectrum for compound PUYRISKXBBQECH-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:05,701:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:05,702:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:05,702:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound PUYRISKXBBQECH-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound PUYRISKXBBQECH-UHFFFAOYSA-N

# %%
#perform spectrum search for each row by InChiKey_origin column, and add number of found spectra to the dataframe from each database.
#for positive mode data
for iter, row in postarget.iterrows():
    key = row['InChiKey_origin']
    mbank_spectra = get_spectrum_by_key(mbank_data_pos, key)
    mona_spectra = get_spectrum_by_key(mona_data_pos, key)
    mona_obtrap_spectra = get_spectrum_by_key(mona_obtrap_data_pos, key)
    cfmid_e0_spectra = get_spectrum_by_key(cfmid_e0_data_pos, key)
    cfmid_e1_spectra = get_spectrum_by_key(cfmid_e1_data_pos, key)   
    cfmid_e2_spectra = get_spectrum_by_key(cfmid_e2_data_pos, key)
    postarget.loc[iter, 'mbank_data_pos'] = len(mbank_spectra.keys())
    postarget.loc[iter, 'mona_spectra_pos'] = len(mona_spectra.keys())
    postarget.loc[iter, 'mona_obtrap_spectra_pos'] = len(mona_obtrap_spectra.keys())
    postarget.loc[iter, 'cfmid_e0_spectra_pos'] = len(cfmid_e0_spectra.keys())
    postarget.loc[iter, 'cfmid_e1_spectra_pos'] = len(cfmid_e1_spectra.keys())
    postarget.loc[iter, 'cfmid_e2_spectra_pos'] = len(cfmid_e2_spectra.keys())
    postarget.loc[iter, 'total_spectra_pos'] = len(mbank_spectra.keys()) + len(mona_spectra.keys()) + len(mona_obtrap_spectra.keys()) + len(cfmid_e0_spectra.keys()) + len(cfmid_e1_spectra.keys()) + len(cfmid_e2_spectra.keys())


#extract the experimental spectrum for each compound
for iter, row in postarget.iterrows():
    if row['total_spectra_pos'] == 0:
        print(f'no reference spectra found for this compound {row["InChiKey_origin"]}')
        continue
    
    #perform spectrum similarity for each database
    query_spectrums =[]
    #extract the experimental spectrum
    key = row['InChiKey_origin']
    print(f'Searching for compound {key}')

    target_mz = row['Average Mz']
    injection_id = row['MSMS_injection']
    q_filepath = os.path.join("D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/", f"{injection_id}.mzML")

    celevel = [10,20,40]
    
    for ce in celevel:
        ms2_query = preprocess_spectra(q_filepath, target_mz, ce, tolerance=peak_int_tol)
        if ms2_query is None:
            print(f'No spectra found for compound {key} with CE {ce}')
            continue
        sspectrum = Spectrum(mz = normalize_and_filter(ms2_query[0], baseline=peak_norm_tol)[0],
                             intensities = normalize_and_filter(ms2_query[0], baseline=peak_norm_tol)[1], 
                             metadata = {"inchikey": key, 'peak_comments':  str(ce)+'eV'})
        query_spectrums.append(sspectrum)
    print(f'number of query spectra found for compound {key} {len(query_spectrums)}')
    print(f'finished extracting experimental spectrum for compound {key}----------------------------------------')
    
    #############
    #extract the reference database spectra for each compound
    reference_spectrums_library = []
    reference_spectrums_insilico =[]

    if row['mbank_data_pos'] > 0:
        mbank_spectra = get_spectrum_by_key(mbank_data_pos, key)
        for ce, spectra in mbank_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {'inchikey': key, 'peak_comments': 'mbank' + '_'+ str(ce)})
                reference_spectrums_library.append(reference)

    if row['mona_spectra_pos'] > 0:
        mona_spectra = get_spectrum_by_key(mona_data_pos, key)
        for ce, spectra in mona_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'mona' + '_'+ str(ce)})
                reference_spectrums_library.append(reference)

    if row['mona_obtrap_spectra_pos'] > 0:
        mona_obtrap_spectra = get_spectrum_by_key(mona_obtrap_data_pos, key)
        for ce, spectra in mona_obtrap_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'mona_obtrap' + '_'+ str(ce)})
                reference_spectrums_library.append(reference)

    if row['cfmid_e0_spectra_pos'] > 0:
        cfmid_e0_spectra = get_spectrum_by_key(cfmid_e0_data_pos, key)
        for ce, spectra in cfmid_e0_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'cfmid_e0' + '_'+ str(ce)})
                reference_spectrums_insilico.append(reference)

    if row['cfmid_e1_spectra_pos'] > 0:
        cfmid_e1_spectra = get_spectrum_by_key(cfmid_e1_data_pos, key)
        for ce, spectra in cfmid_e1_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'cfmid_e1' + '_'+ str(ce)})
                reference_spectrums_insilico.append(reference)
        
    if row['cfmid_e2_spectra_pos'] > 0:
        cfmid_e2_spectra = get_spectrum_by_key(cfmid_e2_data_pos, key)
        for ce, spectra in cfmid_e2_spectra.items():
            for sspectrum in spectra:
                reference = Spectrum(mz = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[0], 
                                    intensities = normalize_and_filter(sspectrum, baseline=peak_norm_tol)[1],
                                    metadata = {"inchikey": key, 'peak_comments': 'cfmid_e3' + '_'+ str(ce)})
                reference_spectrums_insilico.append(reference)

    print(f'finished extracting reference spectrum for compound {key}----------------------------------------')
    
#calculate the similarity score for each database
    print(f'Spectrum similarity-----------------')
    print(f'number of library spectra found for this compound {len(reference_spectrums_library)}')
    print(f'number of insilico spectra found for this compound {len(reference_spectrums_insilico)}')
    # print(reference_spectrums[1].metadata)


    if len(reference_spectrums_library) > 0:
        try:
            scores = matchms.calculate_scores(references = reference_spectrums_library,
                                        queries = query_spectrums,
                                        similarity_function = CosineGreedy(tolerance=match_tolerance, 
                                                                        mz_power=1.3, 
                                                                        intensity_power=0.53),
                                        is_symmetric = False)
            
            best_scores_library, best_spectrums_library, best_match_querys_library = [], [],[]

            for i in range(len(query_spectrums)):
                query = query_spectrums[i]
                best_matches = scores.scores_by_query(query,'CosineGreedy_score', sort=True)
                for (reference, score) in best_matches:
                    best_scores_library.append(score[0])
                    best_spectrums_library.append(reference.metadata['peak_comments'])
                    best_match_querys_library.append(query.metadata['peak_comments'])

            #get the highest score and the corresponding database
            if best_scores_library:
                best_score_library = max(best_scores_library)
                best_spectrum_library = best_spectrums_library[best_scores_library.index(best_score_library)]
                best_match_query_library = best_match_querys_library[best_scores_library.index(best_score_library)]

            else:
                best_score_library = None
                best_spectrum_library = None
                best_match_query_library = None
        
        except IndexError:
            print(f'No match found for compound {key}')
            best_score_library = None
            best_spectrum_library = None
            best_match_query_library = None
        
        except ValueError:
            print(f'No match found for compound {key}')
            best_score_library = None
            best_spectrum_library = None
            best_match_query_library = None
    else:
        best_score_library = None
        best_spectrum_library = None
        best_match_query_library = None
     

    if len(reference_spectrums_insilico) > 0:
        try:
            scores = matchms.calculate_scores(references = reference_spectrums_insilico,
                                        queries = query_spectrums,
                                        similarity_function = CosineGreedy(tolerance=match_tolerance, 
                                                                        mz_power=1.3, 
                                                                        intensity_power=0.53),
                                        is_symmetric = False)
            
            best_scores_insilico, best_spectrums_insilico, best_match_querys_insilico = [], [],[]

            for i in range(len(query_spectrums)):
                query = query_spectrums[i]
                best_matches = scores.scores_by_query(query,'CosineGreedy_score', sort=True)
                for (reference, score) in best_matches:
                    best_scores_insilico.append(score[0])
                    best_spectrums_insilico.append(reference.metadata['peak_comments'])
                    best_match_querys_insilico.append(query.metadata['peak_comments'])

            #get the highest score and the corresponding database
            if best_scores_insilico:
                best_score_insilico = max(best_scores_insilico)
                best_spectrum_insilico = best_spectrums_insilico[best_scores_insilico.index(best_score_insilico)]
                best_match_query_insilico = best_match_querys_insilico[best_scores_insilico.index(best_score_insilico)]

            else:
                best_score_insilico = None
                best_spectrum_insilico = None
                best_match_query_insilico = None
        
        except IndexError:
            print(f'No match found for compound {key}')
            best_score_insilico = None
            best_spectrum_insilico = None
            best_match_query_insilico = None
        
        except ValueError:
            print(f'No match found for compound {key}')
            best_score_insilico = None
            best_spectrum_insilico = None
            best_match_query_insilico = None
    else:
        best_score_insilico = None
        best_spectrum_insilico = None
        best_match_query_insilico = None
    
    postarget.loc[iter, 'library_best_match'] = best_spectrum_library
    postarget.loc[iter, 'library_best_match_query'] = best_match_query_library
    postarget.loc[iter, 'library_best_match_score_value'] = best_score_library
    postarget.loc[iter, 'insilico_best_match'] = best_spectrum_insilico
    postarget.loc[iter, 'insilico_best_match_query'] = best_match_query_insilico
    postarget.loc[iter, 'insilico_best_match_score_value'] = best_score_insilico

    print(f'Finished spectrum matching for compound {key}')
# Out:
# Searching for compound UYTPUPDQBNUYGX-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 21
# 2024-12-29 14:19:07,356:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 21
# 2024-12-29 14:19:08,646:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 21
# 2024-12-29 14:19:09,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound UYTPUPDQBNUYGX-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound UYTPUPDQBNUYGX-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:09,871:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,877:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,882:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,886:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,891:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,897:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,901:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,906:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,909:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,911:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,914:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,918:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,920:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,922:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,925:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,927:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,931:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,934:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,936:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,938:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,940:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,941:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,942:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,945:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,948:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,951:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,953:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,957:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,959:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,960:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,961:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,962:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,963:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,963:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,964:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,965:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,966:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,967:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,968:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,968:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,969:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,970:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,970:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,972:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,973:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:09,973:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound UYTPUPDQBNUYGX-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 43
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound UYTPUPDQBNUYGX-UHFFFAOYSA-N
# Searching for compound UPOVSWVIQVHMOK-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:19:11,099:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:19:12,175:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:19:13,263:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound UPOVSWVIQVHMOK-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound UPOVSWVIQVHMOK-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:13,266:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:13,267:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:13,267:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound UPOVSWVIQVHMOK-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound UPOVSWVIQVHMOK-UHFFFAOYSA-N
# Searching for compound PODVJTKDNVRRMS-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:14,416:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:15,602:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:16,867:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound PODVJTKDNVRRMS-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound PODVJTKDNVRRMS-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:16,868:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:16,869:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:16,870:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound PODVJTKDNVRRMS-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound PODVJTKDNVRRMS-UHFFFAOYSA-N
# no reference spectra found for this compound LIQUIQYZHDBODX-UHFFFAOYSA-N
# Searching for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 27
# 2024-12-29 14:19:18,057:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 27
# 2024-12-29 14:19:19,187:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 27
# 2024-12-29 14:19:20,338:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:20,339:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,340:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,340:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,341:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,342:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,343:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,344:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,345:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,346:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,346:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,347:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,348:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,349:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,350:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:20,350:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 12
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N
# no reference spectra found for this compound UWEHKQXAACULAX-UHFFFAOYSA-N
# Searching for compound OWRCNXZUPFZXOS-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 12
# 2024-12-29 14:19:21,614:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 12
# 2024-12-29 14:19:22,889:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 12
# 2024-12-29 14:19:24,042:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound OWRCNXZUPFZXOS-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound OWRCNXZUPFZXOS-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:24,046:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,048:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,049:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,050:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,051:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,052:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,053:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,054:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,055:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,056:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,057:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,058:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,058:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,059:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,060:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,061:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,062:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,063:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,064:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,064:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,065:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,066:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,066:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,067:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,068:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,069:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,069:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,071:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,073:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,073:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,074:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,075:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,075:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,077:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,078:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,078:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,078:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,079:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,079:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,080:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,080:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,081:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,082:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,082:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:24,083:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound OWRCNXZUPFZXOS-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 48
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound OWRCNXZUPFZXOS-UHFFFAOYSA-N
# Searching for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 31
# 2024-12-29 14:19:25,564:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 31
# 2024-12-29 14:19:27,033:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 31
# 2024-12-29 14:19:28,486:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:28,488:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:28,489:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:28,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N
# Searching for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 31
# 2024-12-29 14:19:30,045:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 31
# 2024-12-29 14:19:31,529:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 31
# 2024-12-29 14:19:33,059:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:33,062:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:33,063:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:33,064:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N
# no reference spectra found for this compound LIQUIQYZHDBODX-UHFFFAOYSA-N
# Searching for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 27
# 2024-12-29 14:19:34,223:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 27
# 2024-12-29 14:19:35,301:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 27
# 2024-12-29 14:19:36,381:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:36,382:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,383:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,384:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,384:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,385:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,386:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,387:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,387:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,388:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,389:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,390:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,391:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,391:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:36,392:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 12
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MCJGNVYPOGVAJF-UHFFFAOYSA-N
# no reference spectra found for this compound UWEHKQXAACULAX-UHFFFAOYSA-N
# Searching for compound CMHMMKSPYOOVGI-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:37,534:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:38,752:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:39,953:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound CMHMMKSPYOOVGI-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound CMHMMKSPYOOVGI-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:39,954:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:39,954:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:39,955:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound CMHMMKSPYOOVGI-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound CMHMMKSPYOOVGI-UHFFFAOYSA-N
# Searching for compound MGZFVSUXQXCEHM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:41,121:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:42,239:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:43,315:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound MGZFVSUXQXCEHM-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound MGZFVSUXQXCEHM-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:43,317:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:43,318:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:43,318:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound MGZFVSUXQXCEHM-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound MGZFVSUXQXCEHM-UHFFFAOYSA-N
# Searching for compound QELSKZZBTMNZEB-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:44,433:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:45,615:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:46,785:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound QELSKZZBTMNZEB-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound QELSKZZBTMNZEB-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:46,786:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,787:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,788:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,789:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,789:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,791:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,791:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,792:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,793:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,793:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,794:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,795:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,798:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,798:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,799:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,800:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:46,801:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound QELSKZZBTMNZEB-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 15
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound QELSKZZBTMNZEB-UHFFFAOYSA-N
# Searching for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:47,944:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:49,055:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 8
# 2024-12-29 14:19:50,125:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:50,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:50,127:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:50,129:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound ZXLYYQUMYFHCLQ-UHFFFAOYSA-N
# Searching for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:51,535:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:53,119:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:54,491:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:54,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,495:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,496:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,496:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,497:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,497:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,499:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,500:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,500:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,501:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,502:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,503:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,505:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,505:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,506:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,507:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,508:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,509:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,510:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,511:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,512:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,512:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,513:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,514:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,515:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,516:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,517:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,519:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,520:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,521:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,522:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,523:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,524:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,524:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,525:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:54,526:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 38
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N
# Searching for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:56,017:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:57,496:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 17
# 2024-12-29 14:19:59,069:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:19:59,070:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,071:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,072:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,073:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,076:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,078:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,080:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,087:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,093:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,098:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,103:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,108:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:19:59,112:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 10
# number of insilico spectra found for this compound 3
# No match found for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N
# Finished spectrum matching for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N
# Searching for compound TWYISXLZCIVDDW-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:00,400:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:01,582:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:02,683:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound TWYISXLZCIVDDW-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound TWYISXLZCIVDDW-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:02,684:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:02,685:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:02,686:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound TWYISXLZCIVDDW-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound TWYISXLZCIVDDW-UHFFFAOYSA-N
# Searching for compound KVOOZKISXYTWCJ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:03,784:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:04,808:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:05,954:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound KVOOZKISXYTWCJ-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound KVOOZKISXYTWCJ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:05,957:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:05,958:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:05,958:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound KVOOZKISXYTWCJ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound KVOOZKISXYTWCJ-UHFFFAOYSA-N
# Searching for compound ADGJZVKOKVENDN-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:07,132:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:08,275:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 10
# 2024-12-29 14:20:09,332:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound ADGJZVKOKVENDN-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound ADGJZVKOKVENDN-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:09,333:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:09,334:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:09,335:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound ADGJZVKOKVENDN-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound ADGJZVKOKVENDN-UHFFFAOYSA-N
# Searching for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:20:10,366:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:20:11,498:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:20:12,678:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:12,679:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,680:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,682:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,684:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,686:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,687:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,687:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,688:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,689:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,690:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,690:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,691:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,692:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,693:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,694:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,694:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,695:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,695:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,696:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,696:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,697:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,698:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,698:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,699:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,702:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,703:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,703:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,704:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,705:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,706:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,706:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,707:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,708:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,708:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,709:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,709:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,710:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,710:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,711:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,714:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:12,716:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 38
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound SMWDFEZZVXVKRB-UHFFFAOYSA-N
# Searching for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:20:13,980:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:20:15,236:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:20:16,353:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:16,354:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,355:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,356:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,356:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,357:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,358:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,359:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,359:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,360:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,360:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,361:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,362:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:16,362:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 10
# number of insilico spectra found for this compound 3
# No match found for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N
# Finished spectrum matching for compound AWJUIBRHMBBTKR-UHFFFAOYSA-N
# Searching for compound SJIXRGNQPBQWMK-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:17,790:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:19,192:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:20,568:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound SJIXRGNQPBQWMK-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound SJIXRGNQPBQWMK-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:20,572:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:20,574:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:20,575:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound SJIXRGNQPBQWMK-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound SJIXRGNQPBQWMK-UHFFFAOYSA-N
# Searching for compound BEWCNXNIQCLWHP-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:21,965:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:23,362:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:24,723:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound BEWCNXNIQCLWHP-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound BEWCNXNIQCLWHP-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:20:24,725:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:24,728:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:24,728:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:24,729:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:24,733:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:20:24,734:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound BEWCNXNIQCLWHP-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 3
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound BEWCNXNIQCLWHP-UHFFFAOYSA-N
# Searching for compound SZWMBBRKRKJARM-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:26,210:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 16
# 2024-12-29 14:20:27,605:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 16
# ...
# 2024-12-29 14:22:52,531:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,532:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,533:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,533:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,534:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,534:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,535:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,536:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,537:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,538:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,539:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,539:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,540:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,541:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,544:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,545:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,545:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,546:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,547:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,548:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,548:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,549:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,550:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,550:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,551:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,552:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,553:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,554:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,555:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,556:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,556:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,557:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,559:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,559:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,561:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,562:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,562:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,563:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,567:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,571:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,574:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,577:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,580:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:52,581:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound DTOSIQBPPRVQHS-PDBXOOCHSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 178
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound DTOSIQBPPRVQHS-PDBXOOCHSA-N
# Searching for compound CDBRNGRSVNBVLJ-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 15
# 2024-12-29 14:22:54,020:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 15
# 2024-12-29 14:22:55,515:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 15
# 2024-12-29 14:22:57,023:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound CDBRNGRSVNBVLJ-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound CDBRNGRSVNBVLJ-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:22:57,025:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:57,026:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:22:57,027:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound CDBRNGRSVNBVLJ-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound CDBRNGRSVNBVLJ-UHFFFAOYSA-N
# Searching for compound ZGGHMDBVRJATBC-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 15
# 2024-12-29 14:22:58,569:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 15
# 2024-12-29 14:22:59,981:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 15
# 2024-12-29 14:23:01,358:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound ZGGHMDBVRJATBC-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound ZGGHMDBVRJATBC-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:23:01,359:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:01,361:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:01,364:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound ZGGHMDBVRJATBC-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound ZGGHMDBVRJATBC-UHFFFAOYSA-N
# no reference spectra found for this compound YFRLAIUAHOVQMA-UHFFFAOYSA-M
# Searching for compound GZIFEOYASATJEH-VHFRWLAGSA-N
# Number of MS2 spectra before merge: 28
# 2024-12-29 14:23:02,671:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 28
# 2024-12-29 14:23:03,786:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 28
# 2024-12-29 14:23:04,920:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound GZIFEOYASATJEH-VHFRWLAGSA-N 3
# finished extracting experimental spectrum for compound GZIFEOYASATJEH-VHFRWLAGSA-N----------------------------------------
# 2024-12-29 14:23:04,922:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:04,923:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:04,923:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:04,925:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:04,926:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:04,926:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound GZIFEOYASATJEH-VHFRWLAGSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 3
# number of insilico spectra found for this compound 3
# No match found for compound GZIFEOYASATJEH-VHFRWLAGSA-N
# Finished spectrum matching for compound GZIFEOYASATJEH-VHFRWLAGSA-N
# Searching for compound XZHNPVKXBNDGJD-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:06,457:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:07,951:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:09,433:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound XZHNPVKXBNDGJD-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound XZHNPVKXBNDGJD-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:23:09,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:09,435:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:09,437:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound XZHNPVKXBNDGJD-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound XZHNPVKXBNDGJD-UHFFFAOYSA-N
# Searching for compound WLRIOEJDMDJFIK-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:10,955:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:12,531:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:13,964:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound WLRIOEJDMDJFIK-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound WLRIOEJDMDJFIK-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:23:13,965:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:13,967:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:13,968:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound WLRIOEJDMDJFIK-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound WLRIOEJDMDJFIK-UHFFFAOYSA-N
# Searching for compound KEROTHRUZYBWCY-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:15,383:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:16,907:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 7
# 2024-12-29 14:23:18,491:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound KEROTHRUZYBWCY-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound KEROTHRUZYBWCY-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:23:18,492:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:18,493:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:18,494:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound KEROTHRUZYBWCY-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound KEROTHRUZYBWCY-UHFFFAOYSA-N
# Searching for compound PZDUWXKXFAIFOR-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:20,122:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:21,576:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:23,053:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound PZDUWXKXFAIFOR-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound PZDUWXKXFAIFOR-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:23:23,055:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:23,055:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:23,057:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound PZDUWXKXFAIFOR-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound PZDUWXKXFAIFOR-UHFFFAOYSA-N
# Searching for compound QYDYPVFESGNLHU-KHPPLWFESA-N
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:24,698:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:26,358:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:27,847:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound QYDYPVFESGNLHU-KHPPLWFESA-N 3
# finished extracting experimental spectrum for compound QYDYPVFESGNLHU-KHPPLWFESA-N----------------------------------------
# 2024-12-29 14:23:27,852:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:27,855:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:27,857:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound QYDYPVFESGNLHU-KHPPLWFESA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound QYDYPVFESGNLHU-KHPPLWFESA-N
# Searching for compound XMONTNNUOWTMGE-UHFFFAOYSA-N
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:29,312:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:30,664:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# Number of MS2 spectra before merge: 24
# 2024-12-29 14:23:32,136:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# number of query spectra found for compound XMONTNNUOWTMGE-UHFFFAOYSA-N 3
# finished extracting experimental spectrum for compound XMONTNNUOWTMGE-UHFFFAOYSA-N----------------------------------------
# 2024-12-29 14:23:32,138:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:32,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 14:23:32,139:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# finished extracting reference spectrum for compound XMONTNNUOWTMGE-UHFFFAOYSA-N----------------------------------------
# Spectrum similarity-----------------
# number of library spectra found for this compound 0
# number of insilico spectra found for this compound 3
# Finished spectrum matching for compound XMONTNNUOWTMGE-UHFFFAOYSA-N

# %%
#update the annotation_RTMS level for each row accroding to the spectrum matching results following the criteria below: 
# RTMSMS level = NotMatched if RTMS = NotMatched
# RTMSMS level 3 for library_best_match_score_value or library_best_match_score_value <0.5 and RTMS = 2 or RTMS =3 or RTMS = 4,
# RTMSMS level 2b for insilico_best_match_score_value >= 0.5 and RTMS = 2 OR RTMS =3,
# RTMSMS level 2a for library_best_match_score_value >= 0.5 and RTMS = 2 or RTMS =3, 
# RTMSMS level = 5 for the rest of the rows
# Replace None values with 0 for comparison
negtarget['library_best_match_score_value'].fillna(0, inplace=True)
negtarget['insilico_best_match_score_value'].fillna(0, inplace=True)
postarget['library_best_match_score_value'].fillna(0, inplace=True)
postarget['insilico_best_match_score_value'].fillna(0, inplace=True)

#convert annoataion_RTMS to string
negtarget['annotation_RTMS'] = negtarget['annotation_RTMS'].astype(str)
postarget['annotation_RTMS'] = postarget['annotation_RTMS'].astype(str)

def update_RTMSMS_level(data):
    for iter, row in data.iterrows():
        library_score = row['library_best_match_score_value']
        insilico_score = row['insilico_best_match_score_value']
        RTMS_level = row['annotation_RTMS']
    
        if RTMS_level == 'NotMatched':
            data.loc[iter, 'RTMSMS_level'] = 'NotMatched'

        elif library_score  >= 0.5:
            if RTMS_level == '2' or RTMS_level == '3' :
               data.loc[iter, 'RTMSMS_level'] = '2a'
            else:
               data.loc[iter, 'RTMSMS_level'] = '3'

        elif library_score  < 0.5 and library_score >0:
            if RTMS_level == '2' or RTMS_level == '3' :
                data.loc[iter, 'RTMSMS_level'] = '3'
            else:
                data.loc[iter, 'RTMSMS_level'] = '5'
        
        elif library_score  == 0 and insilico_score  >= 0.5:
            if RTMS_level == '2' or RTMS_level == '3' :
                data.loc[iter, 'RTMSMS_level'] = '2b'
            else:
                data.loc[iter, 'RTMSMS_level'] = '3'
        
        elif library_score  == 0 and insilico_score  < 0.5 and insilico_score >0:
            data.loc[iter, 'RTMSMS_level'] = '5'
        
        elif library_score == 0 and insilico_score ==0:
            data.loc[iter, 'RTMSMS_level'] = '5'
        else:
            data.loc[iter, 'RTMSMS_level'] = '5'
        
    return data


negtarget = update_RTMSMS_level(negtarget)
postarget = update_RTMSMS_level(postarget)

# %%
postarget.shape
# Out:
# (69, 242)

# %%
postarget.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Pos_AlignmentResults/Matched_peak_pos_spectrum_search_after_library_searching.csv", index=False)
negtarget.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Neg_AlignmentResults/Matched_peak_neg_spectrum_search_after_library_searching.csv", index=False)

# %%
#export the negative and positive suspect features for demographic differences analysis
#combined column 'Average Mz' and 'Average Rt(min)' to form a new column as peak_id, by combining the two columns as in Average Rt(min)_Average Mz
#drop replicated features
negtarget_demogra = negtarget[(negtarget['RTMSMS_level'] == '2a') | (negtarget['RTMSMS_level'] == '2b')]
postarget_demogra = postarget[(postarget['RTMSMS_level'] == '2a') | (postarget['RTMSMS_level'] == '2b')]
negtarget_demogra['peak_id'] = negtarget_demogra['Average Rt(min)'].astype(str) + '_' + negtarget_demogra['Average Mz'].astype(str)
postarget_demogra['peak_id'] = postarget_demogra['Average Rt(min)'].astype(str) + '_' + postarget_demogra['Average Mz'].astype(str)
negtarget_demogra['polarity'] = 'neg'
postarget_demogra['polarity'] = 'pos'
negtarget_demogra = negtarget_demogra.drop_duplicates(subset=['peak_id'])
postarget_demogra = postarget_demogra.drop_duplicates(subset=['peak_id'])
print(f'unique suspect features in negative:{negtarget_demogra.shape}')
print(f'unique suspect features in positive:{postarget_demogra.shape}')



# negtarget_demogra.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Neg_AlignmentResults/Matched_peak_neg__after_annotation_for_demographic.csv", index=False)
# postarget_demogra.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Pos_AlignmentResults/Matched_peak_pos__after_annotation_for_demographic.csv", index=False)

#combined the features and export for demographic analysis
combined_pos_neg_features= pd.concat([negtarget_demogra, postarget_demogra])
#remove column names starts with BH
combined_pos_neg_features = combined_pos_neg_features.loc[:, ~combined_pos_neg_features.columns.str.startswith('BH')]
combined_pos_neg_features.shape
combined_pos_neg_features.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Manuscript/Combined_pos_neg_features_after_annotation_for_demographic.csv", index=False)
# Out:
# unique suspect features in negative:(45, 244)
# unique suspect features in positive:(20, 243)

# %%
##########################################################################################################################
#extract standard spectra from the database and calculate the spetrum between experimental adn the standard spectra
#report the unique number of suspect chemicals by droping duplicated InChiKey_origin and retain rows with RTMSMS_level = 2a or 2b
negtarget['peak_id'] = negtarget['Average Rt(min)'].astype(str) + '_' + negtarget['Average Mz'].astype(str)
postarget['peak_id'] = postarget['Average Rt(min)'].astype(str) + '_' + postarget['Average Mz'].astype(str)
negtarget_unique = negtarget.drop_duplicates(subset=['peak_id'],keep='first')
postarget_unique = postarget.drop_duplicates(subset=['peak_id'], keep='first')
print(f'unique suspect features in negative:{negtarget_unique.shape}') 
print(f'unique suspect features in positive:{postarget_unique.shape}')
negtarget_unique_ch = negtarget.drop_duplicates(subset=['InChiKey_origin'],keep='first')
postarget_unique_ch = postarget.drop_duplicates(subset=['InChiKey_origin'],keep='first')
print(f'unique suspect chemicals in negative:{negtarget_unique_ch.shape}') 
print(f'unique suspect chemicals in positive:{postarget_unique_ch.shape}')

unique_combined = pd.concat([negtarget_unique, postarget_unique])
unique_combined = unique_combined.drop_duplicates(subset=['InChiKey_origin'])
print(f'unique suspect chemicals in combined:{unique_combined.shape}')


negtarget_l2_unique = negtarget[(negtarget['RTMSMS_level'] == '2a') | (negtarget['RTMSMS_level'] == '2b')]
postarget_l2_unique = postarget[(postarget['RTMSMS_level'] == '2a') | (postarget['RTMSMS_level'] == '2b')]
negtarget_l2_unique_feat = negtarget_l2_unique.drop_duplicates(subset=['peak_id'])
postarget_l2_unique_feat = postarget_l2_unique.drop_duplicates(subset=['peak_id'])
print(f'unique suspect features in negative at level 2:{negtarget_l2_unique_feat.shape}') 
print(f'unique suspect features in positive at level 2:{postarget_l2_unique_feat.shape}')


negtarget_l2_unique_ch = negtarget_l2_unique.drop_duplicates(subset=['InChiKey_origin'])
postarget_l2_unique_ch = postarget_l2_unique.drop_duplicates(subset=['InChiKey_origin'])
print(f'unique suspect chemicals in negative at level2:{negtarget_l2_unique_ch.shape}')
print(f'unique suspect chemicals in positive at level2:{postarget_l2_unique_ch.shape}')
#report the unique suspect chemicals after combining negatarget_unique and postarget_unique
unique_combined_l2_unique = pd.concat([negtarget_l2_unique, postarget_l2_unique])
unique_combined_l2_unique = unique_combined_l2_unique.drop_duplicates(subset=['InChiKey_origin'])
print(f'unique suspect chemicals in combined at level2:{unique_combined_l2_unique.shape}')

#export the unique_combined features for manuscript discussions
# unique_combined.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Manuscript/unique_combined_suspect_chemicals_alllevel.csv", index=False)
unique_combined_l2_unique.to_csv("D:/UCSF_postdoc_topic/REVEAL_topics/REVEAL_200samples_analysis/Manuscript/unique_combined_suspect_chemicals_level2.csv", index=False) #use level 2 unqiue chemicals for data analysis
# Out:
# unique suspect features in negative:(79, 243)
# unique suspect features in positive:(37, 242)
# unique suspect chemicals in negative:(190, 243)
# unique suspect chemicals in positive:(57, 242)
# unique suspect chemicals in combined:(90, 253)
# unique suspect features in negative at level 2:(45, 243)
# unique suspect features in positive at level 2:(20, 242)
# unique suspect chemicals in negative at level2:(90, 243)
# unique suspect chemicals in positive at level2:(23, 242)
# unique suspect chemicals in combined at level2:(112, 253)

# %% [markdown]
# ##the following matching the standard spectrum with the experimental spectrum

# %%
# Example usage
# target_mz = 144.04558
target_mz = 498.93015 #y
# target_mz = 398.93625 #n
# target_mz = 212.11842
# q_filepath= "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/B1-10-MSMS-neg_I5.mzML"
# q_filepath= "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/B1-10-MSMS-neg_I4.mzML"
q_filepath= "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/B1-10-MSMS-neg_I2.mzML"
# q_filepath= "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/B1-10-MSMS-neg_I3.mzML"
# q_filepath = "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/NOV22/B1-10-MSMS-pos_I1.mzML"
# ref_filepath = "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/B1-10pool_MSMS_12032024/B1-10_REVEAL_TarMSMS_E502a_r2.mzML"
ref_filepath = "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/B1_10pool_MSMS_12112024/B1_10pool_MSMS_12112024/REVEAL_PFAS-TarMSMS.mzML"
# ref_filepath = "D:/UCSF_postdoc_topic/REVEAL_topics/R200_MSMS/B1-10pool_MSMS_11272024/ENTACT508_pos-TarMSMS.mzML"

ms2_query = preprocess_spectra(q_filepath, target_mz, 40, tolerance=10)
ms2_ref = preprocess_spectra(ref_filepath, target_mz, 40, tolerance=10)

import pyopenms
# spectrum_similarity(ms2_query[0], ms2_ref[0], tolerance = 5.0, baseline = 10)
from pyopenms.plotting import mirror_plot_spectrum
mirror_plot_spectrum(ms2_query[0], ms2_ref[0])

def normalize_and_filter(spectrum, baseline):
    try:
        mz, intensity = spectrum.get_peaks()
    except AttributeError: 
        # mz, intensity = zip(*[(float(m), float(i)) for m, i in spectrum if isinstance(m, (int, float)) and isinstance(i, (int, float))])
        mz, intensity = zip(*spectrum)
        mz = np.array(mz)
        intensity = np.array(intensity)
    except:
        raise ValueError("Please provide a valid spectrum object.")
    
    intensity = np.round((intensity / max(intensity)) * 100, 1)
    indices = np.where(intensity >= baseline)
    return mz[indices], intensity[indices]


#function to get spectrum
def get_spectrum(spectrum):
    try:
        mz, intensity = spectrum.get_peaks()
    except AttributeError:
        mz, intensity = zip(*spectrum)
        mz = np.array(mz)
        intensity = np.array(intensity)
    return mz, intensity

reference = Spectrum(mz=normalize_and_filter(ms2_ref[0], baseline=10)[0], 
                     intensities = normalize_and_filter(ms2_ref[0], baseline=10)[1],
                     metadata={"inchikey": "reference.mzML"})   

query = Spectrum(mz=normalize_and_filter(ms2_query[0], baseline=10)[0], 
                 intensities = normalize_and_filter(ms2_query[0], baseline=10)[1])

print(f'reference spectrum: {reference.get("inchikey")}')

cosine_greedy = CosineGreedy(tolerance=0.005, mz_power=1.3, intensity_power=0.53)
score = cosine_greedy.pair(reference, query)

print(f"Cosine score is {score['score']:.2f} with {score['matches']} matched peaks")

reference.plot_against(query)
# Out:
# Number of MS2 spectra before merge: 7
# Number of MS2 spectra before merge: 24
# 2024-12-29 12:56:52,355:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# 2024-12-29 12:56:52,358:WARNING:matchms:add_precursor_mz:No precursor_mz found in metadata.
# reference spectrum: reference.mzML
# Cosine score is 0.89 with 4 matched peaks
# (<Figure size 1600x1200 with 1 Axes>,
#  <Axes: title={'center': 'Spectrum comparison'}, xlabel='m/z', ylabel='Intensity'>)

# %%
#extract chemical meta information of the unique chemicals at level 2a and 2b 

#plot the number of reported chemicals by bloodexposome and worldexposome

#plot the nubm
